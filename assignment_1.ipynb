# %%
# qua 1 1. Prime Number Checker with Command-Line Arguments

import sys

def is_prime(n):
    """Check if a number is prime."""
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

if __name__ == "__main__":
    if len(sys.argv) !=2:
        print("Usage: python script.py <number>")
    else:
        try:
            num = int(sys.argv[1])
            if is_prime(num):
                print(f"{num} is a prime number.")
            else:
                print(f"{num} is not a prime number.")
        except ValueError:
            print("Please enter a valid integer.")
# Out:
# Please enter a valid integer.

# %% [markdown]
# Python provides command-line arguments through:
#
# 👉 sys.argv
#
# 💠You import it from the standard library:
#
# python:
# import sys
#
#
#  💠          is a list of strings:
#
#     Index	                    Meaning
#
#     sys.argv[0]            Script name (prime_check.py)
#     sys.argv[1]            First argument (your number)
#     sys.argv[2]            Second argument (if any),
#
#     Example:
#
# bash:
#
# python prime_check.py 42
#
#
#     Inside the script:
#
# python:
#
# sys.argv == ["prime_check.py", "42"]
#
#
#     So we use:
#
# python:
#
# num = int(sys.argv[1])
#
#
# to read the number supplied on the command line.

# %%
# 2. Write a program using different data types to demonstrate the 
# difference between ‘is’ and ‘==’. Explain the output.  
# Explanin:
#  👉== checks for value equality.
# 👉is checks for identity (i.e., whether two references point to the same object in memory).

x= 25
y = 256
print(f"x == y: {x == y}") 
print(f"x is y: {x is y}")  
c = 1000
d = 1000
print(f"c == d: {c == d}")  
print(f"c is d: {c is d}")  


list1 = [1, 2, 3, 4, 5]
list2 = [1, 2, 3]
list3 = list1
print(f"list1 == list2: {list1 == list2}")  
print(f"list1 is list2: {list1 is list2}")  
print(f"list1 is list3: {list1 is list3}")
# Out:
# x == y: False
# x is y: False
# c == d: True
# c is d: False
# list1 == list2: False
# list1 is list2: False
# list1 is list3: True

# %% [markdown]
#     📌 Overview
#
# 💠This program demonstrates the difference between Python’s comparison operators:
#
# ▶️== → checks value equality
#
# ▶️is → checks object identity (whether two variables refer to the same object in memory)
#
# The script uses integers and lists to show how these operators behave with different data types.
#
#         📂 File Contents
#
# Python script that compares:
#
# Integers (x, y, c, d)
#
# Lists (list1, list2, list3)
# ✅ Key Takeaways
#
# ▶️Use == to compare values
#
# ▶️Use is to compare identity

# %%
# 3. Write a program that iterates through a list, skips negative numbers, 
# stops execution at zero, and handles non-integer values using exception 
# handling. 
def process_list(lst):
    for item in lst:
        try:
            num = int(item)
            if num < 0:
                print(f"Skipping negative number: {num}")
                continue
            elif num == 0:
                print("Encountered zero. Stopping execution.")
                break
            else:
                print(f"Processing positive number: {num}")
        except ValueError:
            print(f"Non-integer value encountered: {item}")


my_list = [1, -8, 2, 0, 45, "hello", 7.5]
process_list(my_list)
# Out:
# Processing positive number: 1
# Skipping negative number: -8
# Processing positive number: 2
# Encountered zero. Stopping execution.

# %% [markdown]
# List Processing with Exception Handling in Python
# 📌 Objective
#
# This program demonstrates how to:
#
# ▶️Iterate through a list
#
# ▶️Skip negative numbers
#
# ▶️Stop execution when zero is encountered
#
# ▶️Handle non-integer values using exception handling (try / except)
#
# 🧠 Concept Used
#
# ▶️for loop
#
# ▶️Conditional statements (if, elif, else)
#
# ▶️Exception handling (try, except ValueError)
#
# ▶️Type conversion using int()
#
# ▶️Control flow statements (continue, break)

# %%
# 4. Using a single list comprehension, generate a list of squares of numbers 
# from 1 to 20 that are divisible by both 2 and 5. 
squares = [x**2 for x in range(1, 21) if x % 2 == 0 and x % 5 == 0]
print(squares)
# Out:
# [100, 400]

# %% [markdown]
# Squares Using List Comprehension in Python
# 📌 Objective
#
# To generate a list of squares of numbers from 1 to 20 that are divisible by both 2 and 5, using a single list comprehension.
#
# 🧠 Concepts Used
#
# List Comprehension
#
# range() function
#
# Modulus operator (%)
#
# Conditional filtering
#
# Exponent operator (**)

# %%
# 5. Write a user-defined function that returns the largest and smallest 
# values from a list without using built-in functions.  
def find_min_max(lst):
    if not lst:
        return None, None
    smallest = largest = lst[0]
    for num in lst:
        if num < smallest:
            smallest = num
        if num > largest:
            largest = num
    return smallest, largest
numbers = [34, 7, 23, 32, 2, 53]
smallest, largest = find_min_max(numbers)
print(f"Smallest: {smallest}, Largest: {largest}")
# Out:
# Smallest: 2, Largest: 53

# %% [markdown]
# Find Smallest and Largest Values in a List (Without Built-in Functions)
#
# 📌 Objective
#
# To write a user-defined function that finds and returns the smallest and largest values from a list without using built-in functions such as min() or max().
#
# 🧠 Concepts Used
#
# User-defined functions
#
# List traversal using for loop
#
# Conditional statements
#
# Multiple return values
#
# Variable assignment
#
# 📂 Program Description
#
# The function find_min_max():
#
# Checks if the list is empty
#
# Initializes both smallest and largest with the first element
#
# Iterates through the list
#
# Updates:
#
# smallest when a smaller value is found
#
# largest when a larger value is found
#
# Returns both values as a tuple
